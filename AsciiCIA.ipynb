# %%
import json
import re

# %%
cia = []
with open("../factbook.json") as infile:
    for line in infile:
        cia_fact = json.loads(line)
        cia.append(cia_fact)

# %%
asciiArr = []
currCountry = 0
for country in cia:
    try:
        asciiArr[0][currCountry] = country['countryname']
    except:
        print(" ")

# %%
f = open('data_test.ascii', 'w')
for b in asciiArr:
    f.write(b[0]+'\n')
