# %%
import json
import re
from neo4j.v1 import GraphDatabase, basic_auth

# %%
driver = GraphDatabase.driver("bolt://localhost:7687", auth = basic_auth("neo4j", "temppassword1"))
session = driver.session()

# %%
cia = []
with open("../factbook.json") as infile:
    for line in infile:
        cia_fact = json.loads(line)
        cia.append(cia_fact)

# %%
for country in cia: #this will go through cia and plot everything
    b = country['region']
    if b == None:
        c = "None"
    else:
        b = b.replace(" ", "")
        c = re.sub('[^a-zA-Z0-9 \n\.]', '', b)
    
    name = country['countryname']
    code = country['countrycode']
    try:  
        gdp = country['sections']['Economy'][2]['category_data'].split('(')[0] #i think some entry doesnt have brackets
        session.run("MERGE (a: "+c+" {name: {name}, code:{code}, GDP: {gdp}})", {"name": name, "code": code, "gdp": gdp})
    except:
        session.run("MERGE (a: "+c+" {name: {name}, code:{code}})", {"name": name, "code": code})  
    try:
        pop = country['sections']['People and Society'][4]['category_data'].split(' ')[0]
        session.run("MATCH (n {name: {name}}) SET n.population = {pop}", {"name": name, "pop": pop})
    except:
        print("noPop")
        
#     try:
#         govType = country['sections']['Government'][1]['category_data']
#         session.ru
# Out:
# noPop
# noEdge
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-523dcf1b0cfd> in <module>()
#      11     try:
# ---> 12         gdp = country['sections']['Economy'][2]['category_data'].split('(')[0] #i think some entry doesnt have brackets
#      13         session.run("MERGE (a: "+c+" {name: {name}, code:{code}, GDP: {gdp}})", {"name": name, "code": code, "gdp": gdp})
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# <ipython-input-15-523dcf1b0cfd> in <module>()
#      13         session.run("MERGE (a: "+c+" {name: {name}, code:{code}, GDP: {gdp}})", {"name": name, "code": code, "gdp": gdp})
#      14     except:
# ---> 15         session.run("MERGE (a: "+c+" {name: {name}, code:{code}})", {"name": name, "code": code})
#      16     try:
#      17         pop = country['sections']['People and Society'][4]['category_data'].split(' ')[0]
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/neo4j/v1/api.py in run(self, statement, parameters, **kwparameters)
#     301         if not self.has_transaction():
#     302             self._connection.send()
# --> 303             self._connection.fetch()
#     304
#     305         return result
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/neo4j/bolt/connection.py in fetch(self)
#     274         elif summary_signature == FAILURE:
#     275             log_info("S: FAILURE (%r)", summary_metadata)
# --> 276             response.on_failure(summary_metadata or {})
#     277         else:
#     278             raise ProtocolError("Unexpected response message with signature %02X" % summary_signature)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/neo4j/v1/result.py in on_failure(metadata)
#      67             self._session._connection.acknowledge_failure()
#      68             on_footer(metadata)
# ---> 69             raise CypherError.hydrate(**metadata)
#      70
#      71         run_response.on_success = on_header
#
# ClientError: Expected a parameter named isIn

# %%
print (cia[125])
# Out:
# {'sections': {'Government': [{'section_title': 'Government', 'category_name': 'Country name', 'category_data': [{'sub_category_name': 'conventional long form', 'sub_category_data': 'Republic of Kenya'}, {'sub_category_name': 'conventional short form', 'sub_category_data': 'Kenya'}, {'sub_category_name': 'local long form', 'sub_category_data': 'Republic of Kenya/Jamhuri ya Kenya'}, {'sub_category_name': 'local short form', 'sub_category_data': 'Kenya'}, {'sub_category_name': 'former', 'sub_category_data': 'British East Africa'}]}, {'section_title': 'Government', 'category_name': 'Government type', 'category_data': 'republic'}, {'section_title': 'Government', 'category_name': 'Capital', 'category_data': [{'sub_category_name': 'name', 'sub_category_data': 'Nairobi'}, {'sub_category_name': 'geographic coordinates', 'sub_category_data': '1 17 S, 36 49 E'}, {'sub_category_name': 'time difference', 'sub_category_data': 'UTC+3 (8 hours ahead of Washington, DC, during Standard Time)'}]}, {'section_title': 'Government', 'category_name': 'Administrative divisions', 'category_data': "47 counties; Baringo, Bomet, Bungoma, Busia, Elgeyo/Marakwet, Embu, Garissa, Homa Bay, Isiolo, Kajiado, Kakamega, Kericho, Kiambu, Kilifi, Kirinyaga, Kisii, Kisumu, Kitui, Kwale, Laikipia, Lamu, Machakos, Makueni, Mandera, Marsabit, Meru, Migori, Mombasa, Murang'a, Nairobi City, Nakuru, Nandi, Narok, Nyamira, Nyandarua, Nyeri, Samburu, Siaya, Taita/Taveta, Tana River, Tharaka-Nithi, Trans Nzoia, Turkana, Uasin Gishu, Vihiga, Wajir, West Pokot"}, {'section_title': 'Government', 'category_name': 'Independence', 'category_data': '12 December 1963 (from the UK)'}, {'section_title': 'Government', 'category_name': 'National holiday', 'category_data': 'Independence Day, 12 December (1963); Madaraka Day, 1 June (1963); Mashujaa Day, 20 October (2010)'}, {'section_title': 'Government', 'category_name': 'Constitution', 'category_data': 'previous 1963, 1969; latest drafted 6 May 2010, passed by referendum 4 August 2010, promulgated 27 August 2010 (2013)'}, {'section_title': 'Government', 'category_name': 'Legal system', 'category_data': 'mixed legal system of English common law, Islamic law, and customary law; judicial review in a new Supreme Court established pursuant to the new constitution'}, {'section_title': 'Government', 'category_name': 'International law organization participation', 'category_data': 'accepts compulsory ICJ jurisdiction with reservations; accepts ICCt jurisdiction'}, {'section_title': 'Government', 'category_name': 'Suffrage', 'category_data': '18 years of age; universal'}, {'section_title': 'Government', 'category_name': 'Executive branch', 'category_data': [{'sub_category_name': 'chief of state', 'sub_category_data': 'President Uhuru KENYATTA (since 9 April 2013); Deputy President William RUTO (since 9 April 2013); note - the president is both chief of state and head of government'}, {'sub_category_name': 'head of government', 'sub_category_data': 'President Uhuru KENYATTA (since 9 April 2013); Deputy President William RUTO (since 9 April 2013); note - according to the 2008 power sharing agreement the position of prime minister was created though not well defined; consistent with the new constitution, the position was abolished after the March 2013 elections'}, {'sub_category_name': 'cabinet', 'sub_category_data': 'Cabinet appointed by the president'}, {'sub_category_name': 'elections', 'sub_category_data': 'president and deputy president elected on the same ticket by popular vote for a five-year term (eligible for a second term); in addition to receiving a simple majority of votes, the presidential candidate must also win 25% or more of the votes cast in each of more than half of the 47 counties to avoid a runoff; election last held on 4 March 2013 (next to be held in 2017 or 2018); note - the new constitution had set elections for August 2011 but elections were delayed to 2013'}, {'sub_category_name': 'election results', 'sub_category_data':  ...

# %%
print (cia[6]['sections']['Economy'][2]['category_data'].split('(')[0])
# Out:
# $12.8 billion
