# %%
import json
import string
import re

# %%
f = open('../GSREvents.json', 'r')

# %%
# Out:
# {'date': '2013-09-26T00:00:00', 'model': 'GSR', 'description': {'original_text_basis_enrichment': {'langSource': 'Basis-RLI', 'nounPhrases': [{'offset': '1:11', 'expr': 'el marco del día Mundial de la Prevención del Embarazo'}, {'offset': '14:15', 'expr': 'adolescentes'}, {'offset': '16:19', 'expr': 'los grupos juveniles'}, {'offset': '21:22', 'expr': 'Pytyvôhára'}, {'offset': '25:27', 'expr': 'Presencia joven'}, {'offset': '30:31', 'expr': 'Encarnación'}, {'offset': '33:35', 'expr': 'una feria'}, {'offset': '36:38', 'expr': 'el derecho'}, {'offset': '39:41', 'expr': 'la información'}, {'offset': '42:43', 'expr': 'sexualidad'}, {'offset': '48:49', 'expr': 'cabo'}, {'offset': '50:54', 'expr': 'la Plaza Juan E.'}, {'offset': '59:61', 'expr': 'la capital'}, {'offset': '63:66', 'expr': '09.00 a 13.00'}, {'offset': '66:67', 'expr': 'horas'}], 'errorMessage': '', 'tokens': [{'POS': 'PREP', 'value': 'En', 'end': 2, 'lemma': 'en', 'start': 0}, {'POS': 'DETSG', 'value': 'el', 'end': 5, 'lemma
# ...
